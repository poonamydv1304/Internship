# %% [markdown]
# ## Salary Project

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\github_repo\Files\Salaries.csv')
data.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
data.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
df=pd.read_csv('C:\github_repo\Files\Salaries.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
data.shape
# Out:
# (397, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
data.isnull()
# Out:
#       rank  discipline  yrs.since.phd  yrs.service    sex  salary
# 0    False       False          False        False  False   False
# 1    False       False          False        False  False   False
# 2    False       False          False        False  False   False
# 3    False       False          False        False  False   False
# 4    False       False          False        False  False   False
# ..     ...         ...            ...          ...    ...     ...
# 392  False       False          False        False  False   False
# 393  False       False          False        False  False   False
# 394  False       False          False        False  False   False
# 395  False       False          False        False  False   False
# 396  False       False          False        False  False   False
#
# [397 rows x 6 columns]

# %%
data.mean()
# Out:
# C:\Users\poonam\AppData\Local\Temp/ipykernel_20268/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# yrs.since.phd        22.314861
# yrs.service          17.614610
# salary           113706.458438
# dtype: float64

# %%
import seaborn as sns

# %%
sns.scatterplot()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="rank",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x="discipline",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.since.phd",y="salary",data=data)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x="yrs.service",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
sns.scatterplot(x="sex",y="salary",data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('saveimg.png')
plt.show()

# %%
df.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %%
df.corr()['salary'].sort_values()
# Out:
# yrs.service      0.334745
# yrs.since.phd    0.419231
# salary           1.000000
# Name: salary, dtype: float64

# %% [markdown]
# ## Corellation using heatmap

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))

sns.heatmap(df.corr(), annot=True, linewidths=0.5, linecolor="red", fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Outcome of Correlation:

# %% [markdown]
# ## Describing datasets:

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2, annot=True, fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Summary")
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# ## Outcome of Discribe of DataSets:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %% [markdown]
# ## Outliers Checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=14

# %%
collist
# Out:
# array(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex',
#        'salary'], dtype=object)

# %%
for i in range(0, len(collist)):
    print (collist[i])
# Out:
# rank
# discipline
# yrs.since.phd
# yrs.service
# sex
# salary

# %%
df[collist[2]]
# Out:
# 0      19
# 1      20
# 2       4
# 3      45
# 4      40
#        ..
# 392    33
# 393    31
# 394    42
# 395    25
# 396     8
# Name: yrs.since.phd, Length: 397, dtype: int64

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data = df[collist[i]], color='green', orient='v')
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20268/444611380.py in <module>
#       5 for i in range (0,len(collist)):
#       6     plt.subplot(nrows,ncol,i+1)
# ----> 7     sns.boxplot(data = df[collist[i]], color='green', orient='v')
#       8     plt.tight_layout()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...
